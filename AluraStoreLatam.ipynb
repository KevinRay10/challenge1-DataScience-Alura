# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

ingreso_tienda1 = tienda["Precio"].sum()
ingreso_tienda2 = tienda2["Precio"].sum()
ingreso_tienda3 = tienda3["Precio"].sum()
ingreso_tienda4 = tienda4["Precio"].sum()

print("Ingreso total tienda 1:", ingreso_tienda1)
print("Ingreso total tienda 2:", ingreso_tienda2)
print("Ingreso total tienda 3:", ingreso_tienda3)
print("Ingreso total tienda 4:", ingreso_tienda4)

ingresos = [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

ingresos_millones = [i/1_000_000 for i in ingresos]

plt.figure(figsize=(8,5))
barras = plt.bar(tiendas, ingresos_millones, color="skyblue")
plt.title("Ingresos totales por tienda (en millones)")
plt.xlabel("Tienda")
plt.ylabel("Ingreso total (millones)")
plt.ylim(0, max(ingresos_millones) * 1.1)

for barra, valor in zip(barras, ingresos_millones):
    plt.text(barra.get_x() + barra.get_width()/2, valor + 10, f"{valor:.1f}", ha='center', va='bottom', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# Ingreso total tienda 1: 1150880400.0
# Ingreso total tienda 2: 1116343500.0
# Ingreso total tienda 3: 1098019600.0
# Ingreso total tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

categorias_t1 = tienda["Categoría del Producto"].value_counts()
categorias_t2 = tienda2["Categoría del Producto"].value_counts()
categorias_t3 = tienda3["Categoría del Producto"].value_counts()
categorias_t4 = tienda4["Categoría del Producto"].value_counts()

print("Tienda 1:")
print(categorias_t1)
print("\nTienda 2:")
print(categorias_t2)
print("\nTienda 3:")
print(categorias_t3)
print("\nTienda 4:")
print(categorias_t4)

plt.figure(figsize=(5,3))
categorias_t1.plot(kind="barh", color="orange")
plt.title("Distribución de categorías de productos (Tienda 1)")
plt.xlabel("Cantidad vendida")
plt.ylabel("Categoría del Producto")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5,3))
categorias_t2.plot(kind="barh", color="blue")
plt.title("Distribución de categorías de productos (Tienda 2)")
plt.xlabel("Cantidad vendida")
plt.ylabel("Categoría del Producto")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5,3))
categorias_t3.plot(kind="barh", color="green")
plt.title("Distribución de categorías de productos (Tienda 3)")
plt.xlabel("Cantidad vendida")
plt.ylabel("Categoría del Producto")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5,4))
categorias_t2.plot(kind="barh", color="red")
plt.title("Distribución de categorías de productos (Tienda 4)")
plt.xlabel("Cantidad vendida")
plt.ylabel("Categoría del Producto")
plt.tight_layout()
plt.show()
# Out:
# Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)


calificacion_promedio_tienda1 = tienda["Calificación"].mean()
calificacion_promedio_tienda2 = tienda2["Calificación"].mean()
calificacion_promedio_tienda3 = tienda3["Calificación"].mean()
calificacion_promedio_tienda4 = tienda4["Calificación"].mean()

print("Calificación promedio tienda 1:", calificacion_promedio_tienda1)
print("Calificación promedio tienda 2:", calificacion_promedio_tienda2)
print("Calificación promedio tienda 3:", calificacion_promedio_tienda3)
print("Calificación promedio tienda 4:", calificacion_promedio_tienda4)

promedios = [
    calificacion_promedio_tienda1,
    calificacion_promedio_tienda2,
    calificacion_promedio_tienda3,
    calificacion_promedio_tienda4
]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(8,5))
barras = plt.bar(nombres_tiendas, promedios, color='mediumseagreen')

plt.title("Promedio de calificaciones por tienda")
plt.xlabel("Tienda")
plt.ylabel("Calificación promedio")
plt.ylim(0, 5.2)

for barra, promedio in zip(barras, promedios):
    plt.text(barra.get_x() + barra.get_width()/2, promedio + 0.07, f"{promedio:.2f}", ha='center', va='bottom', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# Calificación promedio tienda 1: 3.976685036032217
# Calificación promedio tienda 2: 4.037303942348453
# Calificación promedio tienda 3: 4.048325561678677
# Calificación promedio tienda 4: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

mas_vendidos_tienda1 = tienda["Producto"].value_counts()
mas_vendidos_tienda2 = tienda2["Producto"].value_counts()
mas_vendidos_tienda3 = tienda3["Producto"].value_counts()
mas_vendidos_tienda4 = tienda4["Producto"].value_counts()

print("Tienda 1 - Top 5 más vendidos:")
print(mas_vendidos_tienda1.head(5))
print("\nTienda 1 - Top 5 menos vendidos:")
print(mas_vendidos_tienda1.tail(5))

print("\nTienda 2 - Top 5 más vendidos:")
print(mas_vendidos_tienda2.head(5))
print("\nTienda 2 - Top 5 menos vendidos:")
print(mas_vendidos_tienda2.tail(5))

print("\nTienda 3 - Top 5 más vendidos:")
print(mas_vendidos_tienda3.head(5))
print("\nTienda 3 - Top 5 menos vendidos:")
print(mas_vendidos_tienda3.tail(5))

print("\nTienda 4 - Top 5 más vendidos:")
print(mas_vendidos_tienda4.head(5))
print("\nTienda 4 - Top 5 menos vendidos:")
print(mas_vendidos_tienda4.tail(5))


plt.figure(figsize=(4,4))
mas_vendidos_tienda1.head(5).plot(kind="pie", autopct='%1.1f%%', startangle=90, cmap="Pastel1")
plt.title("Top 5 productos más vendidos (Tienda 1)")
plt.ylabel('')
plt.tight_layout()
plt.show()

plt.figure(figsize=(4,4))
mas_vendidos_tienda2.head(5).plot(kind="pie", autopct='%1.1f%%', startangle=90, cmap="Pastel1")
plt.title("Top 5 productos más vendidos (Tienda 2)")
plt.ylabel('')
plt.tight_layout()
plt.show()

plt.figure(figsize=(4,4))
mas_vendidos_tienda3.head(5).plot(kind="pie", autopct='%1.1f%%', startangle=90, cmap="Pastel1")
plt.title("Top 5 productos más vendidos (Tienda 3)")
plt.ylabel('')
plt.tight_layout()
plt.show()

plt.figure(figsize=(4,4))
mas_vendidos_tienda4.head(5).plot(kind="pie", autopct='%1.1f%%', startangle=90, cmap="Pastel1")
plt.title("Top 5 productos más vendidos (Tienda 4)")
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# Tienda 1 - Top 5 más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
#
# Tienda 1 - Top 5 menos vendidos:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
#
# Tienda 2 - Top 5 más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
#
# Tienda 2 - Top 5 menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
#
# Tienda 3 - Top 5 más vendidos:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)


costo_envio_promedio_tienda1 = tienda["Costo de envío"].mean()
costo_envio_promedio_tienda2 = tienda2["Costo de envío"].mean()
costo_envio_promedio_tienda3 = tienda3["Costo de envío"].mean()
costo_envio_promedio_tienda4 = tienda4["Costo de envío"].mean()

print("Costo de envío promedio tienda 1:", costo_envio_promedio_tienda1)
print("Costo de envío promedio tienda 2:", costo_envio_promedio_tienda2)
print("Costo de envío promedio tienda 3:", costo_envio_promedio_tienda3)
print("Costo de envío promedio tienda 4:", costo_envio_promedio_tienda4)

costos_envio = [costo_envio_promedio_tienda1, costo_envio_promedio_tienda2, costo_envio_promedio_tienda3, costo_envio_promedio_tienda4]
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(6,4))
plt.plot(tiendas, costos_envio, marker='o', linestyle='-', color='red')
plt.title("Costo de envío promedio por tienda")
plt.xlabel("Tienda")
plt.ylabel("Costo de envío promedio")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Costo de envío promedio tienda 1: 26018.60958033065
# Costo de envío promedio tienda 2: 25216.235693090293
# Costo de envío promedio tienda 3: 24805.680373039424
# Costo de envío promedio tienda 4: 23459.457167090754

# %% [markdown]
# 6. **Informe**

# %% [markdown]
# # Informe de análisis comparativo: Selección de tienda a cerrar
#
# ## Introducción
#
# El propósito de este informe es asesorar al Sr. Juan respecto a cuál de sus cuatro tiendas digitales debería considerar cerrar, identificando la de menor rendimiento global. Para fundamentar la decisión, se analizan los ingresos totales, la distribución y el volumen de ventas por categorías, la satisfacción del cliente reflejada en las calificaciones promedio, los productos más y menos vendidos y el costo de envío promedio en cada una.
#
# ---
#
# ## Análisis de resultados
#
# ### 1. Ingresos totales
#
# El gráfico anterior muestró los ingresos totales (en millones) de cada tienda, acá un resumen:
#
#
# Tienda   -------  Ingreso total
#
# Tienda 1  ---    $1,150.88 millones
#
# Tienda 2  ---    $1,116.34 millones
#
# Tienda 3  ---    $1,098.02 millones
#
# Tienda 4  ---    $1,038.38 millones
#
#
#
# **Observación:** Tienda 4 presenta el ingreso total más bajo entre las cuatro tiendas.
#
# ---
#
# ### 2. Volumen y distribución de ventas por categoría
#
# Al comparar el volumen de unidades vendidas por categoría:
#
# | Categoría                | T1 | T2 | T3 | T4 |
# |--------------------------|----|----|----|----|
# | Muebles                  |465 |442 |499 |480 |
# | Electrónicos             |448 |422 |451 |451 |
# | Juguetes                 |324 |313 |315 |338 |
# | Electrodomésticos        |312 |305 |278 |254 |
# | Deportes y diversión     |284 |275 |277 |277 |
# | Instrumentos musicales   |182 |224 |177 |170 |
# | Libros                   |173 |197 |185 |187 |
# | Artículos para el hogar  |171 |181 |177 |201 |
#
# **Observación:**
# - Tienda 4 tiene el menor número de ventas en categorías clave como "Electrodomésticos", "Instrumentos musicales" y no lidera ninguna categoría.
# - Aunque en "Artículos para el hogar" y "Juguetes" tiene buen posicionamiento, esto no compensa el bajo desempeño en las demás.
#
# ---
#
# ### 3. Calificaciones promedio de los clientes
#
# Gráfico de barras de calificaciones promedio por tienda:
#
#
# | Tienda      | Calificación promedio |
# |-------------|-----------------------|
# | Tienda 1    | 3.98                  |
# | Tienda 2    | 4.04                  |
# | Tienda 3    | 4.05                  |
# | Tienda 4    | 3.99                  |
#
# **Observación:** Tienda 4 no es la peor calificada, pero sus resultados son sólo marginalmente mejores que Tienda 1 y quedan por debajo de Tienda 2 y 3.
#
# ---
#
# ### 4. Productos más y menos vendidos
#
# **Tienda 4 - Top 5 más vendidos:**
# - Cama box (62)
# - Cubertería (59)
# - Dashboards con Power BI (56)
# - Cama king (56)
# - Carrito de control remoto (55)
#
# **Tienda 4 - Top 5 menos vendidos:**
# - Refrigerador (38)
# - Ciencia de datos con Python (38)
# - Guitarra acústica (37)
# - Armario (34)
# - Guitarra eléctrica (33)
#
# **Observación:**
# Tienda 4 no muestra productos significativamente destacados en comparación a otras tiendas (por ejemplo, “Cama box”, “Cubertería” y “Carrito de control remoto” no aparecen entre los TOP de las otras tiendas), lo que puede sugerir una menor tracción comercial, menor identificación de best-sellers o surtido menos alineado al mercado.
#
# ---
#
# ### 5. Costo de envío promedio
#
#
# Tienda ---- Costo de envío promedio
#
#
# Tienda 1 ----     $26,018.61
#
# Tienda 2 ----     $25,216.24
#
# Tienda 3 ----     $24,805.68
#
# Tienda 4 ----     $23,459.46
#
#
# **Observación:**
# Aunque la Tienda 4 tiene el costo de envío promedio más bajo, esto no se refleja en un mejor desempeño en ventas ni en mayor satisfacción de cliente.
#
# ---
#
# ## Conclusión y recomendación
#
# El análisis integral indica que **Tienda 4** es la que tiene el rendimiento global más bajo según los siguientes aspectos:
#
# - Es la que **menos ingresa**, marcando una diferencia desfavorable frente a las otras tiendas.
# - No lidera en ninguna categoría clave y sus volúmenes de venta están, en general, por debajo de sus competidoras.
# - Sus calificaciones promedio, aunque superiores a la de Tienda 1, no alcanzan los mejores valores y no muestran fortaleza diferencial.
# - Los productos más vendidos en Tienda 4 no están altamente posicionados, ni muestran patrones claros de alta demanda ante el conjunto de las tiendas.
# - A pesar de tener el costo de envío más bajo, esto no se traduce en mejoras significativas en ventas ni en diferenciación positiva evidente.
#
# **Por tanto, se recomienda cerrar la Tienda 4,** dado que su rendimiento en ingresos, ventas por categoría, posicionamiento de productos y satisfacción del cliente es globalmente inferior al del resto de las tiendas.
